# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import cv2

# %%
model_dir = 'centernet_mobilenetv2_fpn_od'

# %%
model = keras.models.load_model(model_dir + '/saved_model')
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.
# /home/me/miniconda3/envs/dsml/lib/python3.9/site-packages/keras/layers/core/lambda_layer.py:303: UserWarning: google3.third_party.tensorflow.python.ops.nn_ops is not loaded, but a Lambda layer uses it. It may cause errors.
#   function = cls._parse_function_from_config(config, custom_objects,

# %%
img = cv2.imread('test.png', 1)
plt.imshow(img)
plt.show()

# %%
model
# Out:
# <tensorflow.python.saved_model.load.Loader._recreate_base_user_object.<locals>._UserObject at 0x7fb165a86b80>
